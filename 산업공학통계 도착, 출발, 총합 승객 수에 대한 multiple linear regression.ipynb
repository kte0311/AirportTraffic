# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# 첫 번째 엑셀 파일 경로 지정
excel_file = 'C:/Users/emgkrla/Desktop/Data2/y.xlsx'
df1 = pd.read_excel(excel_file)

# 두 번째 엑셀 파일 경로 지정
excel_file1 = 'C:/Users/emgkrla/Desktop/Data2/x.xlsx'
df2 = pd.read_excel(excel_file1)

# 두 DataFrame을 'year-month' 열을 기준으로 병합
merged_data = pd.merge(df1, df2, on='year-month')

# 독립 변수(X)와 종속 변수(y) 설정
# 여러 독립 변수를 포함한 DataFrame 생성
X = merged_data[['temp', 'won exchange rate', '100 yen exchange rate', 'Yuan exchange rate']]
y = merged_data['total']  # 종속 변수

# 상수항 추가 (statsmodels에서는 수동으로 상수항을 추가해야 함)
X = sm.add_constant(X)  # 상수항 추가

# statsmodels를 사용하여 다중 선형 회귀 모델 생성 및 학습
model = sm.OLS(y, X).fit()

# 학습된 모델의 요약 통계 출력
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  total   R-squared:                       0.366
# Model:                            OLS   Adj. R-squared:                  0.344
# Method:                 Least Squares   F-statistic:                     16.57
# Date:                Mon, 02 Dec 2024   Prob (F-statistic):           9.45e-11
# Time:                        23:53:46   Log-Likelihood:                -1886.7
# No. Observations:                 120   AIC:                             3783.
# Df Residuals:                     115   BIC:                             3797.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  4.393e+07   5.11e+06      8.598      0.000    3.38e+07    5.41e+07
# ...

# %%
X = merged_data[['temp', 'won exchange rate', '100 yen exchange rate', 'Yuan exchange rate']]
y1 = merged_data['arrivals']  # 종속 변수

# 상수항 추가 (statsmodels에서는 수동으로 상수항을 추가해야 함)
X = sm.add_constant(X)  # 상수항 추가

# statsmodels를 사용하여 다중 선형 회귀 모델 생성 및 학습
model = sm.OLS(y1, X).fit()

# 학습된 모델의 요약 통계 출력
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               arrivals   R-squared:                       0.363
# Model:                            OLS   Adj. R-squared:                  0.341
# Method:                 Least Squares   F-statistic:                     16.40
# Date:                Mon, 02 Dec 2024   Prob (F-statistic):           1.18e-10
# Time:                        23:54:59   Log-Likelihood:                -1805.3
# No. Observations:                 120   AIC:                             3621.
# Df Residuals:                     115   BIC:                             3635.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  2.226e+07   2.59e+06      8.585      0.000    1.71e+07    2.74e+07
# ...

# %%
X = merged_data[['temp', 'won exchange rate', '100 yen exchange rate', 'Yuan exchange rate']]
y2 = merged_data['departure']  # 종속 변수

# 상수항 추가 (statsmodels에서는 수동으로 상수항을 추가해야 함)
X = sm.add_constant(X)  # 상수항 추가

# statsmodels를 사용하여 다중 선형 회귀 모델 생성 및 학습
model = sm.OLS(y2, X).fit()

# 학습된 모델의 요약 통계 출력
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              departure   R-squared:                       0.370
# Model:                            OLS   Adj. R-squared:                  0.348
# Method:                 Least Squares   F-statistic:                     16.88
# Date:                Mon, 02 Dec 2024   Prob (F-statistic):           6.48e-11
# Time:                        23:55:37   Log-Likelihood:                -1803.3
# No. Observations:                 120   AIC:                             3617.
# Df Residuals:                     115   BIC:                             3631.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  2.213e+07   2.55e+06      8.675      0.000    1.71e+07    2.72e+07
# ...
